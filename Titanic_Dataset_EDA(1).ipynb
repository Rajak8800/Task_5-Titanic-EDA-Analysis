# %% [markdown]
# # Titanic Passengers Data EDA using Python

# %% [markdown]
# ## EDA Exploratory Data Analysis

# %% [markdown]
# ## Import Python Libraries doing EDA

# %%
import pandas as pd 
import numpy as np 
import matplotlib .pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### 1. Load data on python

# %%
Data=pd.read_csv("C:\\Users\\User\\Downloads\\Titanic_EDA_Python\\EDA-main\\Titanic.csv")

# %%
Data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 2.Print starting 10 rows and last 10 rows

# %%
Data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
Data.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ### 3. Shape of the data

# %%
Data.shape
# Out:
# (891, 12)

# %% [markdown]
# ### 4. Print all columns name

# %%
Data.columns.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %% [markdown]
# ### 5. Find the data type of all the columns

# %%
Data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ### 6. Print information and summary

# %%
Data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### 7. Count Survived and show on pie chart

# %%
Survived_count=Data.Survived.value_counts()

# %%
Survived_count
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# #### Survived Count shown in Pie Chart

# %%
plt.pie(Survived_count ,shadow=True, autopct='%0.2f%%', labels=["Not-Survived","Survived"], colors=['Red',"Green"])
plt.title("Survived and Not-Survived Passengers")
plt.show()

# %% [markdown]
# ### 8. Find out how many female passengers had travelled in first class and show on pie chart

# %%
SexRatio_Count=Data.Sex.value_counts()
SexRatio_Count
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
Female_Count=Data[Data.Sex=="female"]
Female_Count
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
Female_Pass=Female_Count.Pclass.value_counts()
Female_Pass
# Out:
# Pclass
# 3    144
# 1     94
# 2     76
# Name: count, dtype: int64

# %%
plt.pie(Female_Pass ,shadow=True ,autopct='%0.2f%%', labels=["Third_Class","First_Class","Second_Class"],explode= (0,0.1,0))
plt.title("Female Passengers Travel in Different Classes")
plt.show()

# %% [markdown]
# ### 9.Find out how many female passengers had Survived and her age <30, show on pie chart and bar chart

# %%
Data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
Female_Age=Female_Count[Female_Count.Age<30]
Female_Age
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 14            15         0       3
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 880          881         1       2
# 882          883         0       3
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
FemaleAge=Data[(Data.Sex=="female") & (Data.Age<30)]
FemaleAge
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 14            15         0       3
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 880          881         1       2
# 882          883         0       3
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Female_survived_Count=FemaleAge.Survived.value_counts()
Female_survived_Count
# Out:
# Survived
# 1    105
# 0     42
# Name: count, dtype: int64

# %%
plt.pie(Female_survived_Count,shadow=True,autopct="%0.2f%%",labels=["Survived","Not_Survived"],explode=(0.1,0))
plt.title("Female Passengers with age <30" )
plt.show()

# %% [markdown]
# ### 10.Find out how many male passengers had Survived and his age >40, show on pie chart

# %%
Male_pass=Data[(Data.Sex=="male") &(Data.Age>40)]
Male_pass
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 33            34         0       2           Wheadon, Mr. Edward H  male
# 35            36         0       1  Holverson, Mr. Alexander Oskar  male
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius  male
# 62            63         0       1     Harris, Mr. Henry Birkhardt  male
# ..           ...       ...     ...                             ...   ...
# 845          846         0       3             Abbing, Mr. Anthony  male
# 851          852         0       3             Svensson, Mr. Johan  male
# 857          858         1       1          Daly, Mr. Peter Denis   male
# 860          861         0       3         Hansen, Mr. Claus Peter  male
# 873          874         0       3     Vander Cruyssen, Mr. Victor  male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %%
Male_sur_count=Male_pass.Survived.value_counts()
Male_sur_count
# Out:
# Survived
# 0    84
# 1    18
# Name: count, dtype: int64

# %%
plt.pie(Male_sur_count,shadow=True, labels=["Not_Survived","Survived"],colors=["red","Green"],autopct="%0.2f%%",explode=(0,0.1))
plt.title("Male Passengers with age >40")
plt.show()

# %% [markdown]
# ### 11. Show age with 20 bins

# %%
Data.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
import numpy as np

# %%
plt.hist(Data.Age,bins=20, color="yellow",edgecolor='green')
plt.title("Age Distribution")
plt.xticks(np.arange(0,84,4))
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
import numpy as np

# %%
counts,bins,_=plt.hist(Data.Age,bins=20,color="Yellow",edgecolor="red" ,label="Age_Bins")
plt.xticks(np.arange(0,84,4))
bin_centers=(bins[:-1]+bins[1:])/2
plt.plot(bin_centers,counts, marker='o' ,label="Age Distribution")
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %%
bin_centers=(bins[:-1]+bins[1:])/2

# %%
bin_centers
# Out:
# array([ 2.4095,  6.3885, 10.3675, 14.3465, 18.3255, 22.3045, 26.2835,
#        30.2625, 34.2415, 38.2205, 42.1995, 46.1785, 50.1575, 54.1365,
#        58.1155, 62.0945, 66.0735, 70.0525, 74.0315, 78.0105])

# %% [markdown]
# ### 12.Show age frequency with survived and not survived (Histogram)

# %%
surv1=Data[Data.Survived==1].Age
surv1
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 875    15.0
# 879    56.0
# 880    25.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 342, dtype: float64

# %%
counts,bins,_=plt.hist(surv1, bins=20,color="yellow",edgecolor="red", label="Age_Bins")
bin_centers=(bins[:-1]+bins[1:])/2
plt.plot(bin_centers,counts,marker='o', label ='Age Distribution')
plt.xticks(np.arange(0,84,4))
plt.title("Survived Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %%
surv0=Data[Data.Survived==0].Age
surv0
# Out:
# 0      22.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
#        ...
# 884    25.0
# 885    39.0
# 886    27.0
# 888     NaN
# 890    32.0
# Name: Age, Length: 549, dtype: float64

# %%
counts,bins,_=plt.hist(surv0, bins=20,color="yellow",edgecolor="red", label="Age_Bins")
bin_centers=(bins[:-1]+bins[1:])/2
plt.plot(bin_centers,counts,marker='o', label ='Age Distribution')
plt.xticks(np.arange(0,84,4))
plt.title("Not_Survived Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %% [markdown]
# ### 13. Show Bar graph for Survived with male, female, class

# %%
Surv_Data=Data[Data.Survived==1]
Surv_Data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
Surv_Data_Count=Surv_Data.Sex.value_counts()
Surv_Data_Count
# Out:
# Sex
# female    233
# male      109
# Name: count, dtype: int64

# %%
Surv_Data_Class=Surv_Data.Pclass.value_counts()
Surv_Data_Class
# Out:
# Pclass
# 1    136
# 3    119
# 2     87
# Name: count, dtype: int64

# %%
sns.countplot( x="Pclass", hue ="Sex",data=Surv_Data )
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# ### 14.How many passengers are travelled in different classes show in Bar graph

# %%
Pass_data=Data.Pclass.value_counts()
Pass_data
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
counts=list(Pass_data)
counts
# Out:
# [491, 216, 184]

# %%
dict(Pass_data)
# Out:
# {3: 491, 1: 216, 2: 184}

# %%
x=Pass_data.keys()
x
# Out:
# Index([3, 1, 2], dtype='int64', name='Pclass')

# %%
data_count=Pass_data.values
data_count
# Out:
# array([491, 216, 184], dtype=int64)

# %%
val=[]
for i in x:
    if i==1:
        val.append("1st Class")
    elif i==2:
        val.append("2nd Class")
    elif i==3 :
        val.append("3rd Class")

# %%
val
# Out:
# ['3rd Class', '1st Class', '2nd Class']

# %%
plt.bar(val,data_count, color=["Green" ,"Yellow","Red"])
plt.title("Passengers Class")
plt.xlabel("Classes")
plt.ylabel("Count Of Passengers")
plt.grid()
plt.show()

# %% [markdown]
# ### 15.How many passengers are survived with class wise and show in Bar graph

# %%
sns.countplot(Data,x="Pclass", hue="Survived")
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# ###  16.Show Question-13 & Question-14 in subplot

# %%
fig,axs=plt.subplots(1,2 ,figsize=(10,3))
sns.countplot( x="Pclass", hue ="Sex",data=Surv_Data,ax= axs[0])
axs[0].set_title("Survived Passengers for gender_Age")


axs[1].bar(val,data_count, color=["Green" ,"Yellow","Red"])
axs[1].set_title("Passengers Class")
axs[1].set_xlabel("Classes")
axs[1].set_ylabel("Count Of Passengers")
axs[1].grid()


plt.show()

# %% [markdown]
# ### 17.Show Bar graph for Survived with 3rd class male, 1st class female

# %% [markdown]
# ####  Survived with 3rd class male

# %%
Survived_3rdmale= Data[(Data.Sex =="male") & (Data.Pclass==3)].Survived.value_counts()
Survived_3rdmale
# Out:
# Survived
# 0    300
# 1     47
# Name: count, dtype: int64

# %%
Data[(Data.Sex =="male") & (Data.Pclass==3)].Survived.value_counts().plot(kind='bar' ,color=["red","green"])
# Out:
# <Axes: xlabel='Survived'>

# %% [markdown]
# #### 1st Class Female

# %%
Survived_1stfemale= Data[(Data.Sex =="female") & (Data.Pclass==1)].Survived.value_counts()
Survived_1stfemale
# Out:
# Survived
# 1    91
# 0     3
# Name: count, dtype: int64

# %%
Data[(Data.Sex =="female") & (Data.Pclass==1)].Survived.value_counts().plot(kind="bar",color=["g","r"])
# Out:
# <Axes: xlabel='Survived'>

# %% [markdown]
# ### 18.How many passengers are survived / not survived and they are 1st class female

# %%
Survived_1stfemale= Data[(Data.Sex =="female") & (Data.Pclass==1)].Survived.value_counts()
Survived_1stfemale
# Out:
# Survived
# 1    91
# 0     3
# Name: count, dtype: int64

# %%
pd.crosstab(Data['Pclass'],Data["Sex"])
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %%
pd.crosstab(Data["Pclass"],Data["Sex"], margins=True)
# Out:
# Sex     female  male  All
# Pclass
# 1           94   122  216
# 2           76   108  184
# 3          144   347  491
# All        314   577  891

# %% [markdown]
# ### Subplots

# %%
fig,axs=plt.subplots(2,2,figsize=(10,8))

male1=Data[(Data.Sex =="male") & (Data.Pclass==3)].Survived.value_counts()
male1.plot(kind="bar", color=['red','green'],ax=axs[0][0])
axs[0][0].set_title("3rd Class male Passengers")
axs[0][0].set_ylabel("Count of Passengers")


female1=Data[(Data.Sex =="female") & (Data.Pclass==1)].Survived.value_counts()
female1.plot(kind="bar", color=['g','r'],ax=axs[0][1])
axs[0][1].set_title("1st Class female Passengers")
axs[0][1].set_ylabel("Count of Passengers")

sns.countplot( x="Pclass", hue ="Sex",data=Surv_Data,ax= axs[1][0])
axs[1][0].set_title("Survived Passengers for gender_Age")

axs[1][1].pie(Male_sur_count,shadow=True, labels=["Not_Survived","Survived"],colors=["red","Green"],autopct="%0.2f%%",explode=(0,0.1))
axs[1][1].set_title("Male with age >40")
plt.show()

# %% [markdown]
# ### 19. Map the Sex column male=1, female =0

# %%
Data['Sex_']=Data['Sex'].map({'male':1, 'female':0})
Data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 20.Find Null values

# %%
Data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Sex_             0
# dtype: int64

# %% [markdown]
# ### 21.Replace Null value to Median value

# %%
Data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Sex_             0
# dtype: int64

# %%
Data.Age.isnull().sum()
# Out:
# 177

# %%
Data.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
Data["Age"]=Data.Age.fillna(28)

# %% [markdown]
# ### 22.Drop unwanted columns

# %%
Data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Final_Data=cols=["Survived","Pclass","Sex_","Age","SibSp","Parch","Fare","Embarked"]

# %%
Final_Dataset=Data[Final_Data]

# %%
Final_Dataset
# Out:
#      Survived  Pclass  Sex_   Age  SibSp  Parch     Fare Embarked
# 0           0       3     1  22.0      1      0   7.2500        S
# 1           1       1     0  38.0      1      0  71.2833        C
# 2           1       3     0  26.0      0      0   7.9250        S
# 3           1       1     0  35.0      1      0  53.1000        S
# 4           0       3     1  35.0      0      0   8.0500        S
# ..        ...     ...   ...   ...    ...    ...      ...      ...
# 886         0       2     1  27.0      0      0  13.0000        S
# 887         1       1     0  19.0      0      0  30.0000        S
# 888         0       3     0  28.0      1      2  23.4500        S
# 889         1       1     1  26.0      0      0  30.0000        C
# 890         0       3     1  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]
